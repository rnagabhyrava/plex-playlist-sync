# %% [markdown]
# ### Deezer api test

# %%
import deezer

# %%
client = deezer.Client()
client.search('Daft Punk', relation='artist')[0]
# Out:
# <Artist: Daft Punk>

# %%
playlistCodes = ['6614423884', '1313621735', '3155776842']
a = []
for code in playlistCodes:
   a = client.get_playlist(code).tracks

# %%
client.get_playlist(1313621735).tracks[60:80]
# Out:
# [<Track: Botella Tras Botella>,
#  <Track: Save Your Tears>,
#  <Track: Losing My Religion>,
#  <Track: Mood (feat. iann dior)>,
#  <Track: Heartbreak Anniversary>,
#  <Track: Heathens>,
#  <Track: Outside (Better Days)>,
#  <Track: Africa>,
#  <Track: Poblado (Remix)>,
#  <Track: Still D.R.E.>,
#  <Track: Hablame 2>,
#  <Track: Go Crazy>,
#  <Track: Benjamines>,
#  <Track: WAP (feat. Megan Thee Stallion)>,
#  <Track: Levitating>,
#  <Track: Lil Bit (FGL Remix)>,
#  <Track: telepatía>,
#  <Track: The Pressure>,
#  <Track: LA NOCHE DE ANOCHE>,
#  <Track: Hats Off>]

# %%
for i in a:
    print(i.title)
# Out:
# STAY
# Beggin'
# Bad Habits
# INDUSTRY BABY
# Blinding Lights
# MONTERO (Call Me By Your Name)
# good 4 u
# I WANNA BE YOUR SLAVE
# Pepas
# Astronaut In The Ocean
# Yonaguni
# Todo De Ti
# Dance Monkey
# Peaches
# Kiss Me More (feat. SZA)
# Leave The Door Open
# Save Your Tears (Remix)
# Happier Than Ever
# Volví
# Need To Know
# Qué Más Pues?
# Watermelon Sugar
# Take My Breath
# DÁKITI
# Woman
# Entre Nosotros
# bad guy
# Butter
# Levitating (feat. DaBaby)
# Peaches Justin Beiber (Cover)
# The Business
# Pareja Del Año
# drivers license
# AM Remix
# Save Your Tears
# Levitating
# Volando (Remix)
# Ride It
# Roses (Imanbek Remix)
# Arcade
# As the World Caves In
# Permission to Dance
# traitor
# Fiel
# One Way Ticket
# deja vu
# Love Again
# Sobrio
# Losing My Religion
# Friday (feat. Mufasa & Hypeman) (Dopamine Re-Edit)
# Mood (feat. iann dior)
# Another Love
# Beautiful Mistakes
# I Feel It Coming
# Smells Like Teen Spirit
# Meu Pedaço de Pecado
# You Right
# Don't Start Now
# ...

# %%
aa = client.search("Don't Call Me Angel", relation='track')[0]

# %%
aa.as_dict()
# Out:
# {'id': 790914772,
#  'readable': True,
#  'title': 'Don’t Call Me Angel (Charlie’s Angels)',
#  'title_short': 'Don’t Call Me Angel (Charlie’s Angels)',
#  'title_version': '',
#  'link': 'https://www.deezer.com/track/790914772',
#  'duration': 190,
#  'rank': 793493,
#  'explicit_lyrics': False,
#  'explicit_content_lyrics': 0,
#  'explicit_content_cover': 0,
#  'preview': 'https://cdns-preview-2.dzcdn.net/stream/c-2556ae2f17d45b0d55ba95d4f6c6f9e9-6.mp3',
#  'md5_image': '6dbc74dd24f0c390ddf6fb2ca349191d',
#  'artist': {'id': 1562681,
#   'name': 'Ariana Grande',
#   'link': 'https://www.deezer.com/artist/1562681',
#   'picture': 'https://api.deezer.com/artist/1562681/image',
#   'picture_small': 'https://cdns-images.dzcdn.net/images/artist/3b99aa38bc4f58b05d6671c918eeb03e/56x56-000000-80-0-0.jpg',
#   'picture_medium': 'https://cdns-images.dzcdn.net/images/artist/3b99aa38bc4f58b05d6671c918eeb03e/250x250-000000-80-0-0.jpg',
# ...

# %%
track_ids = [track.as_dict()["id"] for track in playlist]

# %%
tra = client.get_track("1126047002")

# %%
tra.as_dict()
# Out:
# {'id': 1126047002,
#  'readable': True,
#  'title': 'positions',
#  'title_short': 'positions',
#  'title_version': '',
#  'isrc': 'USUM72019413',
#  'link': 'https://www.deezer.com/track/1126047002',
#  'share': 'https://www.deezer.com/track/1126047002?utm_source=deezer&utm_content=track-1126047002&utm_term=0_1628625190&utm_medium=web',
#  'duration': 172,
#  'track_position': 12,
#  'disk_number': 1,
#  'rank': 899875,
#  'release_date': '2020-10-30',
#  'explicit_lyrics': False,
#  'explicit_content_lyrics': 3,
#  'explicit_content_cover': 3,
#  'preview': 'https://cdns-preview-4.dzcdn.net/stream/c-4b368b026137cc956a4796cbc98d7d83-4.mp3',
#  'bpm': 0,
#  'gain': -7.8,
#  'available_countries': ['AE',
#   'AF',
#   'AG',
#   'AI',
#   'AL',
#   'AM',
#   'AO',
#   'AQ',
#   'AR',
#   'AS',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BQ',
#   'BR',
#   'BT',
#   'BV',
#   'BW',
# ...

# %% [markdown]
# ### Plex Test
